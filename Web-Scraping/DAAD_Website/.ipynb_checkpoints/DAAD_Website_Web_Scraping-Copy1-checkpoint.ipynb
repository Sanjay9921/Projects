# %% [markdown]
# # Libraries

# %%
import html
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# # Constants and Parameters

# %%
base_url = "https://www.daad.de/en/study-and-research-in-germany/courses-of-study-in-germany/all-study-programmes-in-germany/"

# %%
#Parameter Codes
degree_program_code = "w" #Graduate Courses Code
subject_group = "1-226" #Computer Science Code
degree_type = "37" #Masters Code
institution_type = "2" #University of Applied Sciences Code
course_language = "2" #English Code

# %%
#Parameters
parameters = {
    "hec-degreeProgrammeType":degree_program_code,
    "hec-subjectGroup":subject_group,
    "hec-degreeType":degree_type,
    "hec-institutionType":institution_type,
    "hec-teachingLanguage":course_language
}

# %% [markdown]
# # Functions

# %%
def get_query_info(soup, tag:str, class_name=None, id_name=None):
    
    query_list = []
    
    if class_name!=None:
        for info in soup.find_all(tag, class_=class_name):
            query_list.append(info.text.strip())
    elif id_name!=None:
        for info in soup.findAll(tag, {"id":id_name}):
            query_list.append(info.text.strip())
    else:
        for info in soup.findAll(tag):
            query_list.append(info.text.strip())
        
    return query_list

# %%
def try_info_list(info_list, index):
    if 0<=index<len(info_list):
        return info_list[index]
    else:
        return np.nan

# %%
def get_daad_info(base_url:str, page=1):
    query_path = "?"
    for k,v in parameters.items():
        query_path += f"{k}={v}&"
    
    if page>1:
        query_path += f"hec-p={page}"
    else:
        #Remove the last '&' for the 1st page
        query_path = query_path[:-1]
        
    url = base_url + query_path
    response = requests.get(url)
    response.raise_for_status()
    
    soup = BeautifulSoup(response.content, "html.parser")
    
    #All Universities Names
    universities_names = get_query_info(soup, "h3")
    universities_names = universities_names[2:-8]
    
    #All DAAD info DataFrame
    df_daad = pd.DataFrame()
    
    for i in range(len(universities_names)):
        university_href = str(soup.find_all("a", class_ = "qa-more-link")[i]).split(" ")[9]
        new_path = university_href.split('"')[1]
        university_url = "https://www.daad.de" + new_path
        university_url = html.unescape(university_url)

        response2 = requests.get(university_url)

        soup2 = BeautifulSoup(response2.content, "html.parser")

        #Degree Name
        degree_name = str(soup2.find("h3")).split(">")[1][:-4]

        #Info List 1
        ##Type of Studies, Semesters, Locations
        info_list = get_query_info(soup2, "h4")
        type_of_studies = try_info_list(info_list, 1)
        semesters = try_info_list(info_list, 3)
        locations = try_info_list(info_list, 4)
    
        #Info List 2
        ##Admission semester, learnings, Admission Requirements
        info_list = get_query_info(soup2, "p", class_name="js-dynamic-content")
        admission_semester = try_info_list(info_list, 1)
        learnings = try_info_list(info_list, 2)
        admission_requirements = try_info_list(info_list, 5)
        
        #Info List 3
        ##Tuition Fees
        info_list = get_query_info(soup2, "div", id_name="hsk-detail-fees")
        tuition_fees = "".join(info_list)
        
        #Info List 4
        #Course Language
        info_list = get_query_info(soup2, "div", id_name="hsk-detail-languages")
        course_language = "".join(info_list)

        university_all_info = {
            "Varsity Name": [universities_names[i]],
            "Degree Name": [degree_name],
            "Type of Studies": [type_of_studies],
            "No. of Semesters": [semesters],
            "Varsity Locations":[locations],
            "Admission": [admission_semester],
            "Focus": [learnings],
            "Admission Requirements": [admission_requirements],
            "Tuition Fees": [tuition_fees],
            "Language": [course_language],
            "Link": [str(university_url)]
        }

        df_temp = pd.DataFrame(university_all_info)
        df_daad = pd.concat([df_daad, df_temp])
        
    return df_daad

# %%
df_1 = get_daad_info(base_url)
df_1
# Out:
#                                         Varsity Name  \
# 0                 International School of Management
# 0      SRH University of Applied Sciences Heidelberg
# 0                            Hochschule Schmalkalden
# 0      SRH University of Applied Sciences Heidelberg
# 0           Mittweida University of Applied Sciences
# 0       Hochschule für Angewandte Wissenschaften Hof
# 0  Würzburg-Schweinfurt University of Applied Sci...
# 0             University of Applied Sciences Neu-Ulm
# 0                   Technische Hochschule Deggendorf
# 0       Hochschule für Angewandte Wissenschaften Hof
# 0                         Technische Hochschule Köln
# 0     Bonn-Rhine-Sieg University of Applied Sciences
# 0  Furtwangen University - computer science, tech...
# 0          University of Applied Sciences Emden/Leer
# 0                 Berlin School of Economics and Law
# 0                              Hochschule Nordhausen
# 0          SRH Berlin University of Applied Sciences
# 0          SRH Berlin University of Applied Sciences
# 0  Hochschule der Bayerischen Wirtschaft für ange...
# 0              Berlin University of Applied Sciences
#
#                                          Degree Name  \
# 0                      Applied Business Data Science
# 0                           Applied Computer Science
# 0                           Applied Computer Science
# 0               Applied Data Science &amp; Analytics
# 0  Applied Mathematics for Network and Data Sciences
# 0               Applied Research in Computer Science
# 0                            Artificial Intelligence
# 0         Artificial Intelligence and Data Analytics
# 0           Artificial Intelligence and Data Science
# 0               Artificial Intelligence and Robotics
# 0                                  Automation and IT
# 0                                 Autonomous Systems
# 0                                Business Consulting
# 0           Business Intelligence and Data Analytics
# 0       Business Intelligence and Process Management
# 0               Computer Engineering for IOT SYSTEMS
# 0  Computer Science - Focus on Big Data and Artif...
# 0         Computer Science - Focus on Cyber Security
# 0                                     Cyber Security
# 0                                       Data Science
#
#                                      Type of Studies No. of Semesters  \
# 0  part time degree programmes for professionals,...      4 semesters
# 0                    international course, full time        24 months
# 0                                          full time      4 semesters
# 0                    international course, full time      4 semesters
# 0                    international course, full time      4 semesters
# 0                                          full time      3 semesters
# 0                    international course, full time      3 semesters
# 0                    international course, full time      3 semesters
# 0                    international course, full time      4 semesters
# 0                                          full time      3 semesters
# 0                    international course, full time      4 semesters
# 0  international course, full time, International...      4 semesters
# 0                    international course, full time      3 semesters
# 0  part time degree programmes for professionals,...      3 semesters
# 0                    international course, full time      3 semesters
# 0                                          full time      3 semesters
# 0                    international course, full time      4 semesters
# 0                    international course, full time      4 semesters
# 0                               part time, full time      3 semesters
# 0                                          full time      4 semesters
#
#                                    Varsity Locations  \
# 0  Dortmund, Frankfurt am Main, München, Hamburg,...
# 0                                         Heidelberg
# 0                                       Schmalkalden
# 0                                         Heidelberg
# 0                                          Mittweida
# 0                                                Hof
# 0                                           Würzburg
# 0                                            Neu-Ulm
# 0                                         Deggendorf
# 0                                                Hof
# 0                                        Gummersbach
# 0                                     Sankt Augustin
# 0                                         Furtwangen
# 0                                              Emden
# 0                                             Berlin
# 0                                         Nordhausen
# 0                                             Berlin
# 0                                             Berlin
# 0                                            München
# 0                                             Berlin
#
#                     Admission  \
# 0   Admission in all quarters
# 0  Summer and Winter Semester
# 0        Winter Semester only
# 0  Summer and Winter Semester
# 0        Winter Semester only
# 0  Summer and Winter Semester
# 0        Summer Semester only
# 0        Winter Semester only
# 0        Summer Semester only
# 0  Summer and Winter Semester
# 0        Winter Semester only
# 0  Summer and Winter Semester
# 0        Summer Semester only
# 0  Summer and Winter Semester
# 0        Winter Semester only
# 0  Summer and Winter Semester
# 0  Summer and Winter Semester
# 0  Summer and Winter Semester
# 0  Summer and Winter Semester
# 0        Winter Semester only
#
#                                                Focus  \
# 0  Business Informatics, Statistics, Business Int...
# 0         Business Computing, Multimedia Development
# 0                                     open admission
# 0  Data Management, Big Data, Data Protection, Da...
# 0  Cryptography, Mathematical Network Analysis, C...
# 0       Selection procedure / qualifying examination
# 0  We strongly recommend English proficiency at t...
# 0  Business Intelligence (BI), BI Strategy, BI Or...
# 0  AI, Artificial intelligence (AI), Computationa...
# 0       Selection procedure / qualifying examination
# 0  Automation and Control Technology, Modelling a...
# 0  Safety and Security of Intelligent Systems, Ex...
# 0  Business Process Management, Business Intellig...
# 0  Computer Sciences, Introduction to Data Scienc...
# 0  Business Intelligence, Business Process Manage...
# 0  To address the shortage of professionally qual...
# 0  Cloud Computing, Big Data, Artificial Intellig...
# 0  Cyber Security, Information Security, Informat...
# 0                                Focus on technology
# 0  The degree course is designed in such a way th...
#
#                               Admission Requirements  \
# 0  50 ECTS points in the field of Economics, of w...
# 0  Students who meet the following requirements c...
# 0                                            English
# 0       Selection procedure / qualifying examination
# 0  Missing documents can be submitted by 21.07. o...
# 0                                             German
# 0  Please note any deviations on our homepage www...
# 0                                     open admission
# 0                                     open admission
# 0                                                NaN
# 0  A relevant Diplom or Bachelor's degree from a ...
# 0  First professionally qualifying university deg...
# 0  Qualification for admission to higher educatio...
# 0  Bachelor's degree in a technical field such as...
# 0  - Bachelor's degree or equivalent degree in bu...
# 0                                                See
# 0                                     open admission
# 0                                     open admission
# 0                                     open admission
# 0  Bachelor's degree before the beginning of studies
#
#                                         Tuition Fees  \
# 0  Tuition fee\n    Fees12,450.00 EUR / totalFees...
# 0  Tuition fee\n    Fees750.00 EUR / MonthFees (L...
# 0  Tuition fee\n    Fees130.00 EUR / semesterFees...
# 0  Tuition fee\n    Fees790.00 EUR / MonthFees (L...
# 0  Tuition fee\n    The university may charge tui...
# 0
# 0
# 0
# 0  Tuition fee\n    FeesNo tuition fees, only EUR...
# 0
# 0                   Tuition fee\n    FeesFees (Link)
# 0    Tuition fee\n    FeesCost-covering tuition fees
# 0  Tuition fee\n    4,500 EUR are to be paid at t...
# 0  Tuition fee\n    In the part-time variant, a b...
# 0
# 0                   Tuition fee\n    FeesFees (Link)
# 0  Tuition fee\n    Fees800.00 EUR / MonthFees (L...
# 0  Tuition fee\n    Fees800.00 EUR / MonthFees (L...
# 0  Tuition fee\n    Fees650.00 EUR / MonthFees (L...
# 0     Tuition fee\n    Feesmandatory semester ticket
#
#                                             Language  \
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
#
#                                                 Link
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...

# %%
df_2 = get_daad_info(base_url, page=2)
df_2
# Out:
#                                         Varsity Name  \
# 0                              GISMA Business School
# 0          Rhine-Waal University of Applied Sciences
# 0  Hochschule der Bayerischen Wirtschaft für ange...
# 0                   Technische Hochschule Deggendorf
# 0                         Technische Hochschule Köln
# 0   Dortmund University of Applied Sciences and Arts
# 0      XU Exponential University of Applied Sciences
# 0          SRH Berlin University of Applied Sciences
# 0   Dortmund University of Applied Sciences and Arts
# 0           University of Applied Sciences Offenburg
# 0  Eberswalde University for Sustainable Development
# 0           Karlsruhe University of Applied Sciences
# 0                   Technische Hochschule Deggendorf
# 0               Fulda University of Applied Sciences
# 0           Frankfurt University of Applied Sciences
# 0                   Technische Hochschule Deggendorf
# 0          University of Applied Sciences Emden/Leer
# 0    South Westphalia University of Applied Sciences
# 0          Rhine-Waal University of Applied Sciences
# 0    South Westphalia University of Applied Sciences
#
#                                          Degree Name  \
# 0              Data Science, AI and Digital Business
# 0                             Design and Interaction
# 0    Digital Business Modelling and Entrepreneurship
# 0                                     Digital Health
# 0                                   Digital Sciences
# 0                             Digital Transformation
# 0         Digital Transformation Management (Master)
# 0  Digital Transformation Management - Focus on B...
# 0                       Embedded Systems Engineering
# 0                         Enterprise and IT Security
# 0                      Forest Information Technology
# 0                                          Geomatics
# 0                               Global Public Health
# 0                        Global Software Development
# 0                             High Integrity Systems
# 0     High Performance Computing / Quantum Computing
# 0                             Industrial Informatics
# 0                           Informatics and Business
# 0       Information Engineering and Computer Science
# 0  International Management &amp; Information Sys...
#
#                                      Type of Studies No. of Semesters  \
# 0                                          full time      4 semesters
# 0                    international course, full time      3 semesters
# 0                               part time, full time      3 semesters
# 0                    international course, full time      3 semesters
# 0                                          full time      4 semesters
# 0                                          full time      4 semesters
# 0  part time degree programmes for professionals,...      2 semesters
# 0                    international course, full time      4 semesters
# 0                    international course, full time      4 semesters
# 0                    international course, full time      3 semesters
# 0  international course, full time, International...      4 semesters
# 0  international course, part time, full time, In...      3 semesters
# 0                    international course, full time      3 semesters
# 0         international course, part time, full time      3 semesters
# 0                                          full time      4 semesters
# 0                    international course, full time      3 semesters
# 0                    international course, full time      3 semesters
# 0                                          full time      3 semesters
# 0                    international course, full time      3 semesters
# 0                    international course, full time      3 semesters
#
#    Varsity Locations                   Admission  \
# 0    Potsdam, Berlin  Summer and Winter Semester
# 0      Kamp-Lintfort        Summer Semester only
# 0            München  Summer and Winter Semester
# 0         Deggendorf        Winter Semester only
# 0  Gummersbach, Köln  Summer and Winter Semester
# 0           Dortmund        Winter Semester only
# 0            Potsdam        Winter Semester only
# 0            Hamburg  Summer and Winter Semester
# 0           Dortmund        Winter Semester only
# 0          Offenburg        Winter Semester only
# 0         Eberswalde        Winter Semester only
# 0          Karlsruhe  Summer and Winter Semester
# 0         Deggendorf        Winter Semester only
# 0              Fulda  Summer and Winter Semester
# 0  Frankfurt am Main  Summer and Winter Semester
# 0         Deggendorf        Summer Semester only
# 0              Emden  Summer and Winter Semester
# 0              Hagen  Summer and Winter Semester
# 0      Kamp-Lintfort  Summer and Winter Semester
# 0              Soest        Summer Semester only
#
#                                                Focus  \
# 0  Data Science and AI, General Business Competen...
# 0  Media Design, Creative Technologies, Digital I...
# 0  This HDBW Master's programme is aimed at gradu...
# 0  Healthcare, eHealth, Research and Methodology,...
# 0  IT Management, Business Information Systems, S...
# 0  Pre-application process:\nThe Course Managemen...
# 0                                     open admission
# 0  Data Analytics, Change Management, Process Man...
# 0  The course is aimed at graduates of Bachelor's...
# 0  Corporate Security, Information Technology, Et...
# 0  Space Data Concepts, Geographical Information ...
# 0  Applicants with a first geo-related degree, wh...
# 0  Students from diverse backgrounds in medicine,...
# 0                               Software Development
# 0  Graduates of the computer science or courses w...
# 0            Quantum Algorithms, Real-time Computing
# 0  Computer Science, Electrical Engineering, Indu...
# 0  ERP and Analytical Systems, IT Quality Management
# 0  Transport Industry, Software Engineering, IT-B...
# 0  Company Management, Organisational Management,...
#
#                               Admission Requirements  \
# 0                              22,000.00 EUR / total
# 0                                            English
# 0  Ideally 210 ECTS, but at least 180 ECTS.\nFor ...
# 0                                     open admission
# 0  Please note that there may be different deadli...
# 0                                            English
# 0                                            English
# 0  A qualifying degree in Economics or Business I...
# 0  Bachelor of Science or Bachelor of Engineering...
# 0  TOEFL iBT 79 or IELTS 6.0, German A2, APS (onl...
# 0  scientific university degree: Bachelor's degre...
# 0  Please note deviating deadlines for Master’s c...
# 0  Completion of an undergraduate degree at a uni...
# 0                                     open admission
# 0  Admission is limited \; Admission is determine...
# 0           Recruitment test \nLanguage requirements
# 0                               selection by the HEI
# 0                                     open admission
# 0                                            English
# 0  210 credits from prior Bachelor or Master stud...
#
#                                         Tuition Fees  \
# 0  Tuition fee\n    Fees22,000.00 EUR / totalFees...
# 0                   Tuition fee\n    FeesFees (Link)
# 0  Tuition fee\n    Fees650.00 EUR / MonthFees (L...
# 0  Tuition fee\n    FeesNo tuition fees, only EUR...
# 0  Tuition fee\n    FeesFees (Link)Please note th...
# 0
# 0  Tuition fee\n    Fees5,070.00 EUR / semesterFe...
# 0  Tuition fee\n    Fees800.00 EUR / MonthFees (L...
# 0
# 0
# 0
# 0  Tuition fee\n    FeesFees (Link)As a rule, EUR...
# 0  Tuition fee\n    FeesNo tuition fees, only EUR...
# 0                   Tuition fee\n    FeesFees (Link)
# 0                   Tuition fee\n    FeesFees (Link)
# 0  Tuition fee\n    FeesNo tuition fees, only EUR...
# 0                   Tuition fee\n    FeesFees (Link)
# 0
# 0                   Tuition fee\n    FeesFees (Link)
# 0
#
#                                             Language  \
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
# 0  Languages of instruction\n    Main languageEng...
#
#                                                 Link
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
# 0  https://www.daad.de/en/study-and-research-in-g...
